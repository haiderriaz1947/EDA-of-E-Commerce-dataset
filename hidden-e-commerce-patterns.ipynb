# %% [markdown]
# # Hidden Patterns in E-Commerce Data You Shouldn’t Ignore 👀
# # 📊 **E-Commerce Data Analysis (EDA)**
#
# This notebook performs Exploratory Data Analysis (EDA) on an e-commerce dataset. It includes data cleaning, visualization, and key business insights.
#
# #### 🔗 GitHub Repo: https://github.com/haiderriaz1947/EDA-of-E-Commerce-dataset
# #### 🚀 Streamlit App: https://eda-of-e-commerce-dataset-yzi4hyyqptu2nldnwsmk3h.streamlit.app/

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('dark_background')
sns.set_palette("viridis")

# %% [markdown]
# ## 📂 Load Dataset

# %%
url = "https://raw.githubusercontent.com/haiderriaz1947/EDA-of-E-Commerce-dataset/main/ecommerce_dataset%20.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    order_id  customer_id  product_id     category  quantity   price  discount  \
# 0         1         1102         464  Electronics         3  466.22      0.07
# 1         2         1435         104       Sports         4  201.52      0.11
# 2         3         1860         218         Home         3   48.11      0.11
# 3         4         1270         388       Sports         3  310.45      0.02
# 4         5         1106         473  Electronics         3   61.35      0.11
#
#             order_date region    payment_method
# 0  2023-01-01 00:00:00   West  Cash on Delivery
# 1  2023-01-01 01:00:00  South       Credit Card
# 2  2023-01-01 02:00:00  South       Credit Card
# 3  2023-01-01 03:00:00  South        Debit Card
# 4  2023-01-01 04:00:00   East       Credit Card

# %% [markdown]
# ## 🔍 Dataset Overview

# %%
df.shape, df.info(), df.isnull().sum(), df.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        1000 non-null   int64
#  1   customer_id     1000 non-null   int64
#  2   product_id      1000 non-null   int64
#  3   category        1000 non-null   object
#  4   quantity        1000 non-null   int64
#  5   price           1000 non-null   float64
#  6   discount        1000 non-null   float64
#  7   order_date      1000 non-null   object
#  8   region          1000 non-null   object
#  9   payment_method  1000 non-null   object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 78.3+ KB
# ((1000, 10),
#  None,
#  order_id          0
#  customer_id       0
#  product_id        0
#  category          0
#  quantity          0
#  price             0
#  discount          0
#  order_date        0
#  region            0
#  payment_method    0
#  dtype: int64,
# ...

# %% [markdown]
# ## 🧹 Data Cleaning & Feature Engineering

# %%
if "price" in df.columns:
    df["price"] = df["price"].astype(float)

if {"price", "quantity", "discount"}.issubset(df.columns):
    df["sales"] = df["price"] * df["quantity"] * (1 - df["discount"])

if "order_date" in df.columns:
    df["order_date"] = pd.to_datetime(df["order_date"], errors="coerce")
    df["day_name"] = df["order_date"].dt.day_name()

df.head()
# Out:
#    order_id  customer_id  product_id     category  quantity   price  discount  \
# 0         1         1102         464  Electronics         3  466.22      0.07
# 1         2         1435         104       Sports         4  201.52      0.11
# 2         3         1860         218         Home         3   48.11      0.11
# 3         4         1270         388       Sports         3  310.45      0.02
# 4         5         1106         473  Electronics         3   61.35      0.11
#
#            order_date region    payment_method      sales day_name
# 0 2023-01-01 00:00:00   West  Cash on Delivery  1300.7538   Sunday
# 1 2023-01-01 01:00:00  South       Credit Card   717.4112   Sunday
# 2 2023-01-01 02:00:00  South       Credit Card   128.4537   Sunday
# 3 2023-01-01 03:00:00  South        Debit Card   912.7230   Sunday
# 4 2023-01-01 04:00:00   East       Credit Card   163.8045   Sunday

# %% [markdown]
# ## 🛒 Category Analysis

# %%
# Converted Plot (Matplotlib / Seaborn)

plt.figure()
plt.plot(df.select_dtypes(include='number').iloc[:,0])
plt.title("Converted Visualization")
plt.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Converted Plot (Matplotlib / Seaborn)

plt.figure()
plt.plot(df.select_dtypes(include='number').iloc[:,0])
plt.title("Converted Visualization")
plt.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 🌍 Regional Analysis

# %%
# Converted Plot (Matplotlib / Seaborn)

plt.figure()
plt.plot(df.select_dtypes(include='number').iloc[:,0])
plt.title("Converted Visualization")
plt.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 📦 Product Analysis

# %%
# Converted Plot (Matplotlib / Seaborn)

plt.figure()
plt.plot(df.select_dtypes(include='number').iloc[:,0])
plt.title("Converted Visualization")
plt.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Converted Plot (Matplotlib / Seaborn)

plt.figure()
plt.plot(df.select_dtypes(include='number').iloc[:,0])
plt.title("Converted Visualization")
plt.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 👥 Customer Analysis

# %%
# Converted Plot (Matplotlib / Seaborn)

plt.figure()
plt.plot(df.select_dtypes(include='number').iloc[:,0])
plt.title("Converted Visualization")
plt.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## ⏱ Time-based Analysis

# %%
# Converted Plot (Matplotlib / Seaborn)

plt.figure()
plt.plot(df.select_dtypes(include='number').iloc[:,0])
plt.title("Converted Visualization")
plt.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 🔗 Correlation Analysis

# %%
numeric_cols = df.select_dtypes(include=[np.number])
plt.figure()
sns.heatmap(numeric_cols.corr(), annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# ## 📌 Conclusion
#
# - Sales trends vary across categories and regions.
# - Certain products and customers contribute most revenue.
# - Time-based trends help identify peak sales days.
# - Correlation analysis highlights relationships between variables.
